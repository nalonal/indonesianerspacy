# %%
import pickle
import spacy
import random
from spacy.util import minibatch, compounding
from spacy import load, displacy

# %%
# data = []
# berita = ('Menteri Dalam Negeri (Mendagri) Tito Karnavian memberikan arahan ke Satpol PP dalam menegakkan aturan PPKM. Tito meminta Satpol PP tidak bertindak layaknya preman ke masyarakat.', {'entities': [(0,30,'ORGANIZATION'),(32,45,'PERSON'),(68,76,'ORGANIZATION')]})

# %%
data = [('Polewali Mandar - Bocah berumur 12 tahun di Kabupaten Polewali Mandar (Polman) bernama Tiara terbaring lemah di rumahSebagian tubuh Tiara mengalami luka parah akibat terkena tumpahan minyak panas hingga kesulitan bergerak', {'entities': [(0,7,"ORGANIZATION"), (54,61,"ORGANIZATION"), (9,14,"ORGANIZATION"), (63,68,"ORGANIZATION"), (18,22,"PERSON"), (24,30,"PERSON"), (32,33,"LOCATION"), (35,39,"LOCATION"), (41,42,"TIME"), (109,110,"TIME"), (44,52,"TIME")]}),('Peristiwa nahas yang menimpa Tiara terjadi di rumah temannya sepulang mengaji', {'entities': [(40,41,"TIME"), (43,44,"TIME")]}),('Kejadian bulan enam lalu', {'entities': [(4,5,"TIME")]}),('Waktu pulang mengaji usai salat zuhur, dia (Tiara) singgah di rumah temannya bantu goreng bakwan', {'entities': [(39,40,"TIME"), (59,60,"TIME")]}),('Sering mampir di sana bantu menggoreng," ujar sang ibu, Irawati, kepada wartawan di rumahnya, Rabu (4/8/2021)', {'entities': [(14,15,"TIME"), (81,82,"TIME")]})]

# %%
# data.append(berita)

# %%
print(data)
# Out:
# [('Polewali Mandar - Bocah berumur 12 tahun di Kabupaten Polewali Mandar (Polman) bernama Tiara terbaring lemah di rumahSebagian tubuh Tiara mengalami luka parah akibat terkena tumpahan minyak panas hingga kesulitan bergerak', {'entities': [(0, 7, 'ORGANIZATION'), (54, 61, 'ORGANIZATION'), (9, 14, 'ORGANIZATION'), (63, 68, 'ORGANIZATION'), (18, 22, 'PERSON'), (24, 30, 'PERSON'), (32, 33, 'LOCATION'), (35, 39, 'LOCATION'), (41, 42, 'TIME'), (109, 110, 'TIME'), (44, 52, 'TIME')]}), ('Peristiwa nahas yang menimpa Tiara terjadi di rumah temannya sepulang mengaji', {'entities': [(40, 41, 'TIME'), (43, 44, 'TIME')]}), ('Kejadian bulan enam lalu', {'entities': [(4, 5, 'TIME')]}), ('Waktu pulang mengaji usai salat zuhur, dia (Tiara) singgah di rumah temannya bantu goreng bakwan', {'entities': [(39, 40, 'TIME'), (59, 60, 'TIME')]}), ('Sering mampir di sana bantu menggoreng," ujar sang ibu, Irawati, kepada wartawan di rumahnya, Rabu (4/8/2021)', {'entities': [(14, 15, 'TIME'), (81, 82, 'TIME')
# ...

# %%
with open('db.pkl', 'wb') as db_file:
    pickle.dump(data, file=db_file)

# %%
with open('db.pkl', 'rb') as f:
    ner_spacy_fmt_datasets = pickle.load(f)
    data = ner_spacy_fmt_datasets

# %%
print(data)
# Out:
# [('Polewali Mandar - Bocah berumur 12 tahun di Kabupaten Polewali Mandar (Polman) bernama Tiara terbaring lemah di rumahSebagian tubuh Tiara mengalami luka parah akibat terkena tumpahan minyak panas hingga kesulitan bergerak', {'entities': [(0, 7, 'ORGANIZATION'), (54, 61, 'ORGANIZATION'), (9, 14, 'ORGANIZATION'), (63, 68, 'ORGANIZATION'), (18, 22, 'PERSON'), (24, 30, 'PERSON'), (32, 33, 'LOCATION'), (35, 39, 'LOCATION'), (41, 42, 'TIME'), (109, 110, 'TIME'), (44, 52, 'TIME')]}), ('Peristiwa nahas yang menimpa Tiara terjadi di rumah temannya sepulang mengaji', {'entities': [(40, 41, 'TIME'), (43, 44, 'TIME')]}), ('Kejadian bulan enam lalu', {'entities': [(4, 5, 'TIME')]}), ('Waktu pulang mengaji usai salat zuhur, dia (Tiara) singgah di rumah temannya bantu goreng bakwan', {'entities': [(39, 40, 'TIME'), (59, 60, 'TIME')]}), ('Sering mampir di sana bantu menggoreng," ujar sang ibu, Irawati, kepada wartawan di rumahnya, Rabu (4/8/2021)', {'entities': [(14, 15, 'TIME'), (81, 82, 'TIME')
# ...
